# %%
#Задание 1
#Дан список вида:
data = [
[13, 25, 23, 34],
[45, 32, 44, 47],
[12, 33, 23, 95],
[13, 53, 34, 35],
]

# %%
#проверка
13+32+23+35
# Out:
# 103

# %%
#Напишите функцию, которая возвращает сумму элементов на диагонали. Т. е. 13+32+23+35.
def Diag(data):
    """считает сумму элементов на главной диагонали матрицы"""
    sumMain = 0
    N = len(data)
    for i in range(N):
        sumMain += data[i][i]
    return sumMain

# %%
Diag(data)
# Out:
# 103

# %%
#Задание 2
#Дан список чисел, часть из которых имеют строковый тип или содержат буквы. 
#Напишите функцию, которая возвращает сумму квадратов элементов, которые могут быть числами.
data = [1, '5', 'abc', 20, '2']

# %%
#проверка
int(data[0])**2+int(data[1])**2+int(data[3])**2+int(data[4])**2
# Out:
# 430

# %%
def kvadrat(n):
    summa = []
    for i in n:
        add=0
        if type(i)==int:
            summa.append(i**2)
        elif type(i)==str:
            for j in i:
                if (j).isalpha():
                    break
                else:
                    add=1
        if add==1:
            summa.append(int(i)**2)
    return sum(summa)

# %%
kvadrat(data)
# Out:
# 430

# %%
#Задание 3
#Напишите функцию, которая возвращает название валюты (поле ‘Name’) с максимальным значением курса с помощью сервиса https://www.cbr-xml-daily.ru/daily_json.js

# %%
import requests

# %%
d = {
    "Date": "2019-05-24T11:30:00+03:00",
    "PreviousDate": "2019-05-23T11:30:00+03:00",
    "PreviousURL": "\/\/www.cbr-xml-daily.ru\/archive\/2019\/05\/23\/daily_json.js",
    "Timestamp": "2019-05-24T05:00:00+03:00",
    "Valute": {
        "AUD": {
            "ID": "R01010",
            "NumCode": "036",
            "CharCode": "AUD",
            "Nominal": 1,
            "Name": "РђРІСЃС‚СЂР°Р»РёР№СЃРєРёР№ РґРѕР»Р»Р°СЂ",
            "Value": 44.2991,
            "Previous": 44.3823
        },
        "AZN": {
            "ID": "R01020A",
            "NumCode": "944",
            "CharCode": "AZN",
            "Nominal": 1,
            "Name": "РђР·РµСЂР±Р°Р№РґР¶Р°РЅСЃРєРёР№ РјР°РЅР°С‚",
            "Value": 38.0143,
            "Previous": 37.9697
        },
        "GBP": {
            "ID": "R01035",
            "NumCode": "826",
            "CharCode": "GBP",
            "Nominal": 1,
            "Name": "Р¤СѓРЅС‚ СЃС‚РµСЂР»РёРЅРіРѕРІ РЎРѕРµРґРёРЅРµРЅРЅРѕРіРѕ РєРѕСЂРѕР»РµРІСЃС‚РІР°",
            "Value": 81.3364,
            "Previous": 81.6854
        },
        "AMD": {
            "ID": "R01060",
            "NumCode": "051",
            "CharCode": "AMD",
            "Nominal": 100,
            "Name": "РђСЂРјСЏРЅСЃРєРёС… РґСЂР°РјРѕРІ",
            "Value": 13.4525,
            "Previous": 13.4409
        },
        "BYN": {
            "ID": "R01090B",
            "NumCode": "933",
            "CharCode": "BYN",
            "Nominal": 1,
            "Name": "Р‘РµР»РѕСЂСѓСЃСЃРєРёР№ СЂСѓР±Р»СЊ",
            "Value": 31.0308,
            "Previous": 31.0781
        },
        "BGN": {
            "ID": "R01100",
            "NumCode": "975",
            "CharCode": "BGN",
            "Nominal": 1,
            "Name": "Р‘РѕР»РіР°СЂСЃРєРёР№ Р»РµРІ",
            "Value": 36.7116,
            "Previous": 36.7669
        },
        "BRL": {
            "ID": "R01115",
            "NumCode": "986",
            "CharCode": "BRL",
            "Nominal": 1,
            "Name": "Р‘СЂР°Р·РёР»СЊСЃРєРёР№ СЂРµР°Р»",
            "Value": 15.9616,
            "Previous": 15.948
        },
        "HUF": {
            "ID": "R01135",
            "NumCode": "348",
            "CharCode": "HUF",
            "Nominal": 100,
            "Name": "Р’РµРЅРіРµСЂСЃРєРёС… С„РѕСЂРёРЅС‚РѕРІ",
            "Value": 21.9679,
            "Previous": 22.0183
        },
        "HKD": {
            "ID": "R01200",
            "NumCode": "344",
            "CharCode": "HKD",
            "Nominal": 10,
            "Name": "Р“РѕРЅРєРѕРЅРіСЃРєРёС… РґРѕР»Р»Р°СЂРѕРІ",
            "Value": 82.165,
            "Previous": 82.0623
        },
        "DKK": {
            "ID": "R01215",
            "NumCode": "208",
            "CharCode": "DKK",
            "Nominal": 10,
            "Name": "Р”Р°С‚СЃРєРёС… РєСЂРѕРЅ",
            "Value": 96.1595,
            "Previous": 96.272
        },
        "USD": {
            "ID": "R01235",
            "NumCode": "840",
            "CharCode": "USD",
            "Nominal": 1,
            "Name": "Р”РѕР»Р»Р°СЂ РЎРЁРђ",
            "Value": 64.4913,
            "Previous": 64.4156
        },
        "EUR": {
            "ID": "R01239",
            "NumCode": "978",
            "CharCode": "EUR",
            "Nominal": 1,
            "Name": "Р•РІСЂРѕ",
            "Value": 71.8369,
            "Previous": 71.8427
        },
        "INR": {
            "ID": "R01270",
            "NumCode": "356",
            "CharCode": "INR",
            "Nominal": 100,
            "Name": "РРЅРґРёР№СЃРєРёС… СЂСѓРїРёР№",
            "Value": 92.4673,
            "Previous": 92.4548
        },
        "KZT": {
            "ID": "R01335",
            "NumCode": "398",
            "CharCode": "KZT",
            "Nominal": 100,
            "Name": "РљР°Р·Р°С…СЃС‚Р°РЅСЃРєРёС… С‚РµРЅРіРµ",
            "Value": 17.0601,
            "Previous": 16.9884
        },
        "CAD": {
            "ID": "R01350",
            "NumCode": "124",
            "CharCode": "CAD",
            "Nominal": 1,
            "Name": "РљР°РЅР°РґСЃРєРёР№ РґРѕР»Р»Р°СЂ",
            "Value": 47.9062,
            "Previous": 48.0821
        },
        "KGS": {
            "ID": "R01370",
            "NumCode": "417",
            "CharCode": "KGS",
            "Nominal": 100,
            "Name": "РљРёСЂРіРёР·СЃРєРёС… СЃРѕРјРѕРІ",
            "Value": 92.3283,
            "Previous": 92.286
        },
        "CNY": {
            "ID": "R01375",
            "NumCode": "156",
            "CharCode": "CNY",
            "Nominal": 10,
            "Name": "РљРёС‚Р°Р№СЃРєРёС… СЋР°РЅРµР№",
            "Value": 93.2171,
            "Previous": 93.3181
        },
        "MDL": {
            "ID": "R01500",
            "NumCode": "498",
            "CharCode": "MDL",
            "Nominal": 10,
            "Name": "РњРѕР»РґР°РІСЃРєРёС… Р»РµРµРІ",
            "Value": 35.7392,
            "Previous": 35.8362
        },
        "NOK": {
            "ID": "R01535",
            "NumCode": "578",
            "CharCode": "NOK",
            "Nominal": 10,
            "Name": "РќРѕСЂРІРµР¶СЃРєРёС… РєСЂРѕРЅ",
            "Value": 73.6337,
            "Previous": 73.6616
        },
        "PLN": {
            "ID": "R01565",
            "NumCode": "985",
            "CharCode": "PLN",
            "Nominal": 1,
            "Name": "РџРѕР»СЊСЃРєРёР№ Р·Р»РѕС‚С‹Р№",
            "Value": 16.6614,
            "Previous": 16.6875
        },
        "RON": {
            "ID": "R01585F",
            "NumCode": "946",
            "CharCode": "RON",
            "Nominal": 1,
            "Name": "Р СѓРјС‹РЅСЃРєРёР№ Р»РµР№",
            "Value": 15.0815,
            "Previous": 15.0952
        },
        "XDR": {
            "ID": "R01589",
            "NumCode": "960",
            "CharCode": "XDR",
            "Nominal": 1,
            "Name": "РЎР”Р  (СЃРїРµС†РёР°Р»СЊРЅС‹Рµ РїСЂР°РІР° Р·Р°РёРјСЃС‚РІРѕРІР°РЅРёСЏ)",
            "Value": 88.8639,
            "Previous": 88.7132
        },
        "SGD": {
            "ID": "R01625",
            "NumCode": "702",
            "CharCode": "SGD",
            "Nominal": 1,
            "Name": "РЎРёРЅРіР°РїСѓСЂСЃРєРёР№ РґРѕР»Р»Р°СЂ",
            "Value": 46.6618,
            "Previous": 46.722
        },
        "TJS": {
            "ID": "R01670",
            "NumCode": "972",
            "CharCode": "TJS",
            "Nominal": 10,
            "Name": "РўР°РґР¶РёРєСЃРєРёС… СЃРѕРјРѕРЅРё",
            "Value": 68.3895,
            "Previous": 68.273
        },
        "TRY": {
            "ID": "R01700J",
            "NumCode": "949",
            "CharCode": "TRY",
            "Nominal": 1,
            "Name": "РўСѓСЂРµС†РєР°СЏ Р»РёСЂР°",
            "Value": 10.504,
            "Previous": 10.5999
        },
        "TMT": {
            "ID": "R01710A",
            "NumCode": "934",
            "CharCode": "TMT",
            "Nominal": 1,
            "Name": "РќРѕРІС‹Р№ С‚СѓСЂРєРјРµРЅСЃРєРёР№ РјР°РЅР°С‚",
            "Value": 18.4524,
            "Previous": 18.4308
        },
        "UZS": {
            "ID": "R01717",
            "NumCode": "860",
            "CharCode": "UZS",
            "Nominal": 10000,
            "Name": "РЈР·Р±РµРєСЃРєРёС… СЃСѓРјРѕРІ",
            "Value": 76.2452,
            "Previous": 76.1557
        },
        "UAH": {
            "ID": "R01720",
            "NumCode": "980",
            "CharCode": "UAH",
            "Nominal": 10,
            "Name": "РЈРєСЂР°РёРЅСЃРєРёС… РіСЂРёРІРµРЅ",
            "Value": 24.5065,
            "Previous": 24.4705
        },
        "CZK": {
            "ID": "R01760",
            "NumCode": "203",
            "CharCode": "CZK",
            "Nominal": 10,
            "Name": "Р§РµС€СЃРєРёС… РєСЂРѕРЅ",
            "Value": 27.8088,
            "Previous": 27.8892
        },
        "SEK": {
            "ID": "R01770",
            "NumCode": "752",
            "CharCode": "SEK",
            "Nominal": 10,
            "Name": "РЁРІРµРґСЃРєРёС… РєСЂРѕРЅ",
            "Value": 66.9143,
            "Previous": 66.8163
        },
        "CHF": {
            "ID": "R01775",
            "NumCode": "756",
            "CharCode": "CHF",
            "Nominal": 1,
            "Name": "РЁРІРµР№С†Р°СЂСЃРєРёР№ С„СЂР°РЅРє",
            "Value": 63.8844,
            "Previous": 63.7463
        },
        "ZAR": {
            "ID": "R01810",
            "NumCode": "710",
            "CharCode": "ZAR",
            "Nominal": 10,
            "Name": "Р®Р¶РЅРѕР°С„СЂРёРєР°РЅСЃРєРёС… СЂСЌРЅРґРѕРІ",
            "Value": 44.5942,
            "Previous": 44.8524
        },
        "KRW": {
            "ID": "R01815",
            "NumCode": "410",
            "CharCode": "KRW",
            "Nominal": 1000,
            "Name": "Р’РѕРЅ Р РµСЃРїСѓР±Р»РёРєРё РљРѕСЂРµСЏ",
            "Value": 54.1003,
            "Previous": 54.1294
        },
        "JPY": {
            "ID": "R01820",
            "NumCode": "392",
            "CharCode": "JPY",
            "Nominal": 100,
            "Name": "РЇРїРѕРЅСЃРєРёС… РёРµРЅ",
            "Value": 58.5141,
            "Previous": 58.329
        }
    }
}

# %%
class Rate:
    def __init__(self, format='value'):
        self.format = format
    
    def exchange_rates(self):
        """
        Возвращает ответ сервиса с информацией о валютах в виде:
        
        {
            'AMD': {
                'CharCode': 'AMD',
                'ID': 'R01060',
                'Name': 'Армянских драмов',
                'Nominal': 100,
                'NumCode': '051',
                'Previous': 14.103,
                'Value': 14.0879
                },
            ...
        }
        """
        r = requests.get('https://www.cbr-xml-daily.ru/daily_json.js')
        return r.json()['Valute']
    
    def make_format(self, currency):
        """
        Возвращает информацию о валюте currency в двух вариантах:
        - полная информация о валюте при self.format = 'full':
        Rate('full').make_format('EUR')
        {
            'CharCode': 'EUR',
            'ID': 'R01239',
            'Name': 'Евро',
            'Nominal': 1,
            'NumCode': '978',
            'Previous': 79.6765,
            'Value': 79.4966
        }
        
        Rate('value').make_format('EUR')
        79.4966
        """
        response = self.exchange_rates()
        
        if currency in response:
            if self.format == 'full':
                return response[currency]
            
            if self.format == 'value':
                return response[currency]['Value']
        
        return 'Error'
    
    def eur(self):
        """Возвращает курс евро на сегодня в формате self.format"""
        return self.make_format('EUR')
    
    def usd(self):
        """Возвращает курс доллара на сегодня в формате self.format"""
        return self.make_format('USD')

# %%
valutes = [[],[]]

for i in d['Valute']:
    valutes[0].append(d['Valute'][i]['Value'])
    valutes[1].append(d['Valute'][i]['CharCode'])
    
valutes[1][valutes[0].index(max(valutes[0]))]
# Out:
# 'DKK'

# %%
sorted(valutes[0], reverse=True)
# Out:
# [96.1595,
#  93.2171,
#  92.4673,
#  92.3283,
#  88.8639,
#  82.165,
#  81.3364,
#  76.2452,
#  73.6337,
#  71.8369,
#  68.3895,
#  66.9143,
#  64.4913,
#  63.8844,
#  58.5141,
#  54.1003,
#  47.9062,
#  46.6618,
#  44.5942,
#  44.2991,
#  38.0143,
#  36.7116,
#  35.7392,
#  31.0308,
#  27.8088,
#  24.5065,
#  21.9679,
#  18.4524,
#  17.0601,
#  16.6614,
#  15.9616,
#  15.0815,
#  13.4525,
#  10.504]
